# %%
def presentarte():       # crear la funcion
  nombre = input("Como te llamas? ")  #pide el nombre
  print("Mucho gusto, " + nombre + "!")  #Muestra mensaje

presentarte()   #Llamas la funcion (la ejecuta)
# Out:
# Como te llamas? messi
# Mucho gusto, messi!
